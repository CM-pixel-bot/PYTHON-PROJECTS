# %% [markdown]
# <a href="https://colab.research.google.com/github/CM-pixel-bot/PYTHON-PROJECTS/blob/main/numpy_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = [1, 3, 5, np.nan, 6]
s = pd.Series(data)
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# dtype: float64

# %%
data_x = pd.Series([0, 1, 2, 3, 4, 5])
data_y = pd.Series([0, 1, 4, 9, 16, 25])
df = pd.DataFrame({'x_value': data_x, 'square(x)': data_y})
print(df)
# Out:
#    x_value  square(x)
# 0        0          0
# 1        1          1
# 2        2          4
# 3        3          9
# 4        4         16
# 5        5         25

# %%
data_x = pd.Series([0, 1, 2, 3, 4, 5])
data_y = pd.Series([0, 1, 4, 9, 16, 25])
df = pd.DataFrame({'x_value': data_x, 'square(x)': data_y})
df
# Out:
#    x_value  square(x)
# 0        0          0
# 1        1          1
# 2        2          4
# 3        3          9
# 4        4         16
# 5        5         25

# %%
dates = pd.date_range("20130101", periods=6)
df_2 = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
print(dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range("20130101", periods=6)
df_2 = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#    x_value  square(x)
# 0        0          0
# 1        1          1
# 2        2          4
# 3        3          9
# 4        4         16
# 5        5         25

# %%
print(df_2.dtypes)
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
dates = pd.date_range("20130101", periods=6)
df_2 = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
print(df_2)
# Out:
#                    A         B         C         D
# 2013-01-01 -2.615732 -0.310786 -2.136456 -0.751582
# 2013-01-02 -0.349004 -0.325826  0.044930 -2.085948
# 2013-01-03  0.378535 -0.706446 -0.184067 -1.284939
# 2013-01-04  0.009407  0.696706 -0.876367 -0.046694
# 2013-01-05 -0.094899  0.336501 -2.720231 -1.378579
# 2013-01-06  2.364670  0.438832 -1.420635  1.132827

# %%
print(df[['x_value', 'square(x)']])
# Out:
#    x_value  square(x)
# 0        0          0
# 1        1          1
# 2        2          4
# 3        3          9
# 4        4         16
# 5        5         25

# %%
import pandas as pd
print(df[1:3])
# Out:
#    x_value  square(x)
# 1        1          1
# 2        2          4

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}
df = pd.DataFrame(data)
df[1:3]
# Out:
#       Name  Age
# 1      Bob   30
# 2  Charlie   35

# %%
population_dict = {'California': 38332521,
'Texas': 26448193,
'Florida': 19552860,
'Illinois': 12882135}
population = pd.Series(population_dict)
print(population_dict,type(population_dict))
print(population,type(population))
# Out:
# {'California': 38332521, 'Texas': 26448193, 'Florida': 19552860, 'Illinois': 12882135} <class 'dict'>
# California    38332521
# Texas         26448193
# Florida       19552860
# Illinois      12882135
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
population['California']
population['California':'Illinois']
# Out:
# California    38332521
# Texas         26448193
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
filtered_df = df[df["Age"] >= 25]
print(filtered_df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
filtered_df = df[df["Age"].isin([35])]
print(filtered_df)
# Out:
#       Name  Age
# 2  Charlie   35

# %%
print(df[df["Age"] >= 25])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
data = {'A': [1, 2, np.nan, 4],
'B': [5, np.nan, 7, 8],
'C': [9, 10, 11, np.nan]}
df = pd.DataFrame(data)
print(df)
# Drop rows with missing values
df.dropna(inplace=True) # Modify df directly
print(df)
# Out:
#      A    B     C
# 0  1.0  5.0   9.0
# 1  2.0  NaN  10.0
# 2  NaN  7.0  11.0
# 3  4.0  8.0   NaN
#      A    B    C
# 0  1.0  5.0  9.0

# %%
data = [2, 4, 6, 8]
mean = sum(data) / len(data)
print(mean)
# Out:
# 5.0

# %%
from statistics import mode
data = [2, 4, 4, 4, 4, 6, 6, 6, 6, 8]
mode_val = mode(data)
print(mode_val)
# Out:
# 4
